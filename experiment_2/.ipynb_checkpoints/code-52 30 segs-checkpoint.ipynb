# %% [markdown]
# #Importação de bibliotecas e funções

# %%
from sklearn.svm import OneClassSVM
from sklearn.linear_model import SGDOneClassSVM
from sklearn.covariance import EllipticEnvelope
from sklearn.metrics import confusion_matrix
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #Experimento 5 - CTU-13 (Captura 52)

# %%
from sklearn.decomposition import FastICA


early_warning_url = "early_warning_exp_2.csv"
early_warning = pd.read_csv(early_warning_url, sep=";")
early_warning
colunas = early_warning.columns[361:]

df = early_warning[colunas]
df = df.fillna(0)
label = pd.read_csv('ctulabel.csv')['maior_2']

init = 97
train = 324
end = 778

x_train = df[init:train]
x_test = df[train:end]
y_real = label[train:end]

# %%
pca = FastICA(n_components=3, random_state=0).fit(x_train)
novo_train  = pca.transform(x_train)
novo_test = []
for i in range (0,16):
    comeco = ((i*30))
    final = (((i+1)*30))
    if(final > end):
        final = end
    print(comeco,final)
    novo_test.append(pca.transform(x_test[comeco:final]))
    
array_kernel = ['linear' , 'poly' , 'rbf' , 'sigmoid' , ] # 'precomputed'
models = []
nu_atual = 0.01
for c in array_kernel:
    while nu_atual <= 0.5:
        models.append(OneClassSVM(gamma='auto', kernel=c, nu=nu_atual).fit(novo_train))
        nu_atual += 0.01
    nu_atual = 0.05

from sklearn.metrics import accuracy_score
for clf in models:
    preds = []
    for i in novo_test:
        y_test = clf.predict(i)
        y_test_final = [0 if i == 1 else 1 for i in y_test]
        preds += y_test_final
    if(accuracy_score(y_real, preds) > 0.83):
        print(clf)
        print(confusion_matrix(y_real, preds))
        print(classification_report(y_real, preds, digits = 4))
# Out:
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# 0 30
# 30 60
# 60 90
# 90 120
# 120 150
# 150 180
# 180 210
# 210 240
# 240 270
# 270 300
# 300 330
# 330 360
# 360 390
# 390 420
# 420 450
# 450 480
# OneClassSVM(gamma='auto', kernel='linear', nu=0.03)
# [[389  52]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9677    0.8821    0.9229       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8568       454
#    macro avg     0.4838    0.4410    0.4614       454
# weighted avg     0.9400    0.8568    0.8965       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.4000000000000002)
# [[394  47]
#  [  8   5]]
#               precision    recall  f1-score   support
#
#            0     0.9801    0.8934    0.9348       441
#            1     0.0962    0.3846    0.1538        13
#
#     accuracy                         0.8789       454
#    macro avg     0.5381    0.6390    0.5443       454
# weighted avg     0.9548    0.8789    0.9124       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.060000000000000005)
# [[411  30]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9693    0.9320    0.9503       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9053       454
#    macro avg     0.4847    0.4660    0.4751       454
# weighted avg     0.9416    0.9053    0.9231       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.16)
# [[380  61]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9669    0.8617    0.9113       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8370       454
#    macro avg     0.4835    0.4308    0.4556       454
# weighted avg     0.9392    0.8370    0.8852       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.17)
# [[386  55]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9674    0.8753    0.9190       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8502       454
#    macro avg     0.4837    0.4376    0.4595       454
# weighted avg     0.9397    0.8502    0.8927       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2700000000000001)
# [[396  45]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9778    0.8980    0.9362       441
#            1     0.0816    0.3077    0.1290        13
#
#     accuracy                         0.8811       454
#    macro avg     0.5297    0.6028    0.5326       454
# weighted avg     0.9521    0.8811    0.9131       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2800000000000001)
# [[396  45]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9778    0.8980    0.9362       441
#            1     0.0816    0.3077    0.1290        13
#
#     accuracy                         0.8811       454
#    macro avg     0.5297    0.6028    0.5326       454
# weighted avg     0.9521    0.8811    0.9131       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2900000000000001)
# [[396  45]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9778    0.8980    0.9362       441
#            1     0.0816    0.3077    0.1290        13
#
#     accuracy                         0.8811       454
#    macro avg     0.5297    0.6028    0.5326       454
# weighted avg     0.9521    0.8811    0.9131       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3000000000000001)
# [[402  39]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9781    0.9116    0.9437       441
#            1     0.0930    0.3077    0.1429        13
#
#     accuracy                         0.8943       454
#    macro avg     0.5356    0.6096    0.5433       454
# weighted avg     0.9528    0.8943    0.9207       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3100000000000001)
# [[402  39]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9781    0.9116    0.9437       441
#            1     0.0930    0.3077    0.1429        13
#
#     accuracy                         0.8943       454
#    macro avg     0.5356    0.6096    0.5433       454
# weighted avg     0.9528    0.8943    0.9207       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3200000000000001)
# [[403  38]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9782    0.9138    0.9449       441
#            1     0.0952    0.3077    0.1455        13
#
#     accuracy                         0.8965       454
#    macro avg     0.5367    0.6108    0.5452       454
# weighted avg     0.9529    0.8965    0.9220       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3300000000000001)
# [[392  49]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9776    0.8889    0.9311       441
#            1     0.0755    0.3077    0.1212        13
#
#     accuracy                         0.8722       454
#    macro avg     0.5265    0.5983    0.5262       454
# weighted avg     0.9517    0.8722    0.9079       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.34000000000000014)
# [[403  38]
#  [  9   4]]
#               precision    recall  f1-score   support
#
#            0     0.9782    0.9138    0.9449       441
#            1     0.0952    0.3077    0.1455        13
#
#     accuracy                         0.8965       454
#    macro avg     0.5367    0.6108    0.5452       454
# weighted avg     0.9529    0.8965    0.9220       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.35000000000000014)
# [[396  45]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9682    0.8980    0.9318       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8722       454
#    macro avg     0.4841    0.4490    0.4659       454
# weighted avg     0.9405    0.8722    0.9051       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.36000000000000015)
# [[396  45]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9682    0.8980    0.9318       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8722       454
#    macro avg     0.4841    0.4490    0.4659       454
# weighted avg     0.9405    0.8722    0.9051       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.37000000000000016)
# [[397  44]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9683    0.9002    0.9330       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8744       454
#    macro avg     0.4841    0.4501    0.4665       454
# weighted avg     0.9406    0.8744    0.9063       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.38000000000000017)
# [[397  44]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9683    0.9002    0.9330       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8744       454
#    macro avg     0.4841    0.4501    0.4665       454
# weighted avg     0.9406    0.8744    0.9063       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3900000000000002)
# [[397  44]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9683    0.9002    0.9330       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8744       454
#    macro avg     0.4841    0.4501    0.4665       454
# weighted avg     0.9406    0.8744    0.9063       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4000000000000002)
# [[396  45]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9682    0.8980    0.9318       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8722       454
#    macro avg     0.4841    0.4490    0.4659       454
# weighted avg     0.9405    0.8722    0.9051       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4100000000000002)
# [[396  45]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9682    0.8980    0.9318       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8722       454
#    macro avg     0.4841    0.4490    0.4659       454
# weighted avg     0.9405    0.8722    0.9051       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4200000000000002)
# [[396  45]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9682    0.8980    0.9318       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8722       454
#    macro avg     0.4841    0.4490    0.4659       454
# weighted avg     0.9405    0.8722    0.9051       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4300000000000002)
# [[396  45]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9682    0.8980    0.9318       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8722       454
#    macro avg     0.4841    0.4490    0.4659       454
# weighted avg     0.9405    0.8722    0.9051       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.46000000000000024)
# [[396  45]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9682    0.8980    0.9318       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8722       454
#    macro avg     0.4841    0.4490    0.4659       454
# weighted avg     0.9405    0.8722    0.9051       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.47000000000000025)
# [[392  49]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9679    0.8889    0.9267       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8634       454
#    macro avg     0.4840    0.4444    0.4634       454
# weighted avg     0.9402    0.8634    0.9002       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.48000000000000026)
# [[389  52]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9677    0.8821    0.9229       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8568       454
#    macro avg     0.4838    0.4410    0.4614       454
# weighted avg     0.9400    0.8568    0.8965       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.49000000000000027)
# [[381  60]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9670    0.8639    0.9126       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8392       454
#    macro avg     0.4835    0.4320    0.4563       454
# weighted avg     0.9393    0.8392    0.8864       454

# %%
from sklearn.decomposition import FactorAnalysis
pca = FactorAnalysis(n_components=3, random_state=0).fit(x_train)
novo_train  = pca.transform(x_train)
novo_test = []
for i in range (0,16):
    comeco = ((i*30))
    final = (((i+1)*30))
    if(final > end):
        final = end
    print(comeco,final)
    novo_test.append(pca.transform(x_test[comeco:final]))
    
array_kernel = ['linear' , 'poly' , 'rbf' , 'sigmoid' , ] # 'precomputed'
models = []
nu_atual = 0.01
for c in array_kernel:
    while nu_atual <= 0.5:
        models.append(OneClassSVM(gamma='auto', kernel=c, nu=nu_atual).fit(novo_train))
        nu_atual += 0.01
    nu_atual = 0.05

from sklearn.metrics import accuracy_score
for clf in models:
    preds = []
    for i in novo_test:
        y_test = clf.predict(i)
        y_test_final = [0 if i == 1 else 1 for i in y_test]
        preds += y_test_final
    if(accuracy_score(y_real, preds) > 0.83):
        print(clf)
        print(confusion_matrix(y_real, preds))
        print(classification_report(y_real, preds, digits = 4))
# Out:
# 0 30
# 30 60
# 60 90
# 90 120
# 120 150
# 150 180
# 180 210
# 210 240
# 240 270
# 270 300
# 300 330
# 330 360
# 360 390
# 390 420
# 420 450
# 450 480
# OneClassSVM(gamma='auto', kernel='linear', nu=0.060000000000000005)
# [[379  62]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9668    0.8594    0.9100       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8348       454
#    macro avg     0.4834    0.4297    0.4550       454
# weighted avg     0.9392    0.8348    0.8839       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.16)
# [[438   3]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9712    0.9932    0.9821       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9648       454
#    macro avg     0.4856    0.4966    0.4910       454
# weighted avg     0.9434    0.9648    0.9539       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.17)
# [[440   1]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9713    0.9977    0.9843       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9692       454
#    macro avg     0.4857    0.4989    0.4922       454
# weighted avg     0.9435    0.9692    0.9562       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.18000000000000002)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.20000000000000004)
# [[434   7]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9709    0.9841    0.9775       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9559       454
#    macro avg     0.4855    0.4921    0.4887       454
# weighted avg     0.9431    0.9559    0.9495       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.2800000000000001)
# [[438   3]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9712    0.9932    0.9821       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9648       454
#    macro avg     0.4856    0.4966    0.4910       454
# weighted avg     0.9434    0.9648    0.9539       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.2900000000000001)
# [[426  15]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9704    0.9660    0.9682       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9383       454
#    macro avg     0.4852    0.4830    0.4841       454
# weighted avg     0.9426    0.9383    0.9405       454
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OneClassSVM(gamma='auto', kernel='linear', nu=0.35000000000000014)
# [[389  52]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9677    0.8821    0.9229       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8568       454
#    macro avg     0.4838    0.4410    0.4614       454
# weighted avg     0.9400    0.8568    0.8965       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.38000000000000017)
# [[408  33]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9691    0.9252    0.9466       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8987       454
#    macro avg     0.4846    0.4626    0.4733       454
# weighted avg     0.9414    0.8987    0.9195       454
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.3900000000000002)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.05)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.060000000000000005)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.07)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.08)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.12999999999999998)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.13999999999999999)
# [[432   9]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9708    0.9796    0.9752       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9515       454
#    macro avg     0.4854    0.4898    0.4876       454
# weighted avg     0.9430    0.9515    0.9472       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.15)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.16)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.17)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.18000000000000002)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.19000000000000003)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.20000000000000004)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.21000000000000005)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.22000000000000006)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.23000000000000007)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.24000000000000007)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.25000000000000006)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.26000000000000006)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2700000000000001)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2800000000000001)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2900000000000001)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3000000000000001)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3100000000000001)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3200000000000001)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3300000000000001)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.34000000000000014)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.35000000000000014)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.36000000000000015)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.37000000000000016)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.38000000000000017)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3900000000000002)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4000000000000002)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4100000000000002)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4200000000000002)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4300000000000002)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4400000000000002)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.45000000000000023)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.46000000000000024)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.47000000000000025)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.48000000000000026)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.49000000000000027)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3, random_state=0).fit(x_train)
novo_train  = pca.transform(x_train)
novo_test = []
for i in range (0,16):
    comeco = ((i*30))
    final = (((i+1)*30))
    if(final > end):
        final = end
    print(comeco,final)
    novo_test.append(pca.transform(x_test[comeco:final]))
    
array_kernel = [ 'poly' , 'rbf' , 'sigmoid' , ] # 'precomputed'
models = []
nu_atual = 0.01
for c in array_kernel:
    while nu_atual <= 0.5:
        models.append(OneClassSVM(gamma='auto', kernel=c, nu=nu_atual).fit(novo_train))
        nu_atual += 0.01
    nu_atual = 0.05

from sklearn.metrics import accuracy_score
for clf in models:
    preds = []
    for i in novo_test:
        y_test = clf.predict(i)
        y_test_final = [0 if i == 1 else 1 for i in y_test]
        preds += y_test_final
    if(accuracy_score(y_real, preds) > 0.83):
        print(clf)
        print(confusion_matrix(y_real, preds))
        print(classification_report(y_real, preds, digits = 4))
# Out:
# 0 30
# 30 60
# 60 90
# 90 120
# 120 150
# 150 180
# 180 210
# 210 240
# 240 270
# 270 300
# 300 330
# 330 360
# 360 390
# 390 420
# 420 450
# 450 480
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.05)
# [[384  57]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9673    0.8707    0.9165       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8458       454
#    macro avg     0.4836    0.4354    0.4582       454
# weighted avg     0.9396    0.8458    0.8902       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.060000000000000005)
# [[413  28]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9695    0.9365    0.9527       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9097       454
#    macro avg     0.4847    0.4683    0.4764       454
# weighted avg     0.9417    0.9097    0.9254       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.07)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.08)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.09)
# [[420  21]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9700    0.9524    0.9611       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9251       454
#    macro avg     0.4850    0.4762    0.4805       454
# weighted avg     0.9422    0.9251    0.9336       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.09999999999999999)
# [[392  49]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9679    0.8889    0.9267       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8634       454
#    macro avg     0.4840    0.4444    0.4634       454
# weighted avg     0.9402    0.8634    0.9002       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.10999999999999999)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.11999999999999998)
# [[389  52]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9677    0.8821    0.9229       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8568       454
#    macro avg     0.4838    0.4410    0.4614       454
# weighted avg     0.9400    0.8568    0.8965       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.12999999999999998)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.13999999999999999)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.15)
# [[388  53]
#  [ 13   0]]
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.16)
# [[430  11]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9707    0.9751    0.9729       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9471       454
#    macro avg     0.4853    0.4875    0.4864       454
# weighted avg     0.9429    0.9471    0.9450       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.17)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.18000000000000002)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.19000000000000003)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.20000000000000004)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.21000000000000005)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.22000000000000006)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.23000000000000007)
# [[441   0]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.9714       454
#    macro avg     0.4857    0.5000    0.4927       454
# weighted avg     0.9436    0.9714    0.9573       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.24000000000000007)
# [[388  53]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9676    0.8798    0.9216       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8546       454
#    macro avg     0.4838    0.4399    0.4608       454
# weighted avg     0.9399    0.8546    0.8952       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.25000000000000006)
# [[380  61]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9669    0.8617    0.9113       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8370       454
#    macro avg     0.4835    0.4308    0.4556       454
# weighted avg     0.9392    0.8370    0.8852       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.26000000000000006)
# [[381  60]
#  [ 13   0]]
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0     0.9670    0.8639    0.9126       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8392       454
#    macro avg     0.4835    0.4320    0.4563       454
# weighted avg     0.9393    0.8392    0.8864       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2700000000000001)
# [[379  62]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9668    0.8594    0.9100       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8348       454
#    macro avg     0.4834    0.4297    0.4550       454
# weighted avg     0.9392    0.8348    0.8839       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2800000000000001)
# [[397  44]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9683    0.9002    0.9330       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8744       454
#    macro avg     0.4841    0.4501    0.4665       454
# weighted avg     0.9406    0.8744    0.9063       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2900000000000001)
# [[379  62]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9668    0.8594    0.9100       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8348       454
#    macro avg     0.4834    0.4297    0.4550       454
# weighted avg     0.9392    0.8348    0.8839       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3000000000000001)
# [[378  63]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9668    0.8571    0.9087       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8326       454
#    macro avg     0.4834    0.4286    0.4543       454
# weighted avg     0.9391    0.8326    0.8826       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3100000000000001)
# [[377  64]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9667    0.8549    0.9073       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8304       454
#    macro avg     0.4833    0.4274    0.4537       454
# weighted avg     0.9390    0.8304    0.8814       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3200000000000001)
# [[377  64]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9667    0.8549    0.9073       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8304       454
#    macro avg     0.4833    0.4274    0.4537       454
# weighted avg     0.9390    0.8304    0.8814       454
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3300000000000001)
# [[377  64]
#  [ 13   0]]
#               precision    recall  f1-score   support
#
#            0     0.9667    0.8549    0.9073       441
#            1     0.0000    0.0000    0.0000        13
#
#     accuracy                         0.8304       454
#    macro avg     0.4833    0.4274    0.4537       454
# weighted avg     0.9390    0.8304    0.8814       454
