# %% [markdown]
# #Importação de bibliotecas e funções

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics import confusion_matrix
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.decomposition import FastICA
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #Experimento 1 - CTU-13 (Captura 51)

# %%
early_warning_url = "early_warning_exp_1.csv"
early_warning = pd.read_csv(early_warning_url, sep=";")

colunas = early_warning.columns[361:]

df = early_warning[colunas]
df = df.fillna(0)
label = pd.read_csv('ctulabel.csv')['maior_2']

init = 880
train = 2934
end = 5632

x_train = df[init:train]
x_test = df[train:end]
y_real = label[train:end]

# %%
pca = FastICA(n_components=9,random_state=0).fit(x_train)
novo_train  = pca.transform(x_train)
novo_test = []
for i in range (0,90):
    comeco = ((i*30))
    final = (((i+1)*30))
    if(final > end):
        final = end
    print(comeco,final)
    novo_test.append(pca.transform(x_test[comeco:final])  )

array_kernel = ['linear' , 'poly' , 'rbf' , 'sigmoid' , ] # 'precomputed'
models = []
nu_atual = 0.05
for c in array_kernel:
    while nu_atual <= 0.5:
        models.append(OneClassSVM(gamma='auto', kernel=c, nu=nu_atual).fit(novo_train))
        nu_atual += 0.01
    nu_atual = 0.05

for clf in models:
    preds = []
    for i in novo_test:
        y_test = clf.predict(i)
        y_test_final = [0 if i == 1 else 1 for i in y_test]
        preds += y_test_final
    if(accuracy_score(y_real, preds) > 0.83):
        print(clf)
        print(confusion_matrix(y_real, preds))
        print(classification_report(y_real, preds, digits = 4))
# Out:
# 0 30
# 30 60
# 60 90
# 90 120
# 120 150
# 150 180
# 180 210
# 210 240
# 240 270
# 270 300
# 300 330
# 330 360
# 360 390
# 390 420
# 420 450
# 450 480
# 480 510
# 510 540
# 540 570
# 570 600
# 600 630
# 630 660
# 660 690
# 690 720
# 720 750
# 750 780
# 780 810
# 810 840
# 840 870
# 870 900
# 900 930
# 930 960
# 960 990
# 990 1020
# 1020 1050
# 1050 1080
# 1080 1110
# 1110 1140
# 1140 1170
# 1170 1200
# 1200 1230
# 1230 1260
# 1260 1290
# 1290 1320
# 1320 1350
# 1350 1380
# 1380 1410
# 1410 1440
# 1440 1470
# 1470 1500
# 1500 1530
# 1530 1560
# 1560 1590
# 1590 1620
# 1620 1650
# 1650 1680
# 1680 1710
# 1710 1740
# 1740 1770
# 1770 1800
# 1800 1830
# 1830 1860
# 1860 1890
# 1890 1920
# 1920 1950
# 1950 1980
# 1980 2010
# 2010 2040
# 2040 2070
# 2070 2100
# 2100 2130
# 2130 2160
# 2160 2190
# 2190 2220
# 2220 2250
# 2250 2280
# 2280 2310
# 2310 2340
# 2340 2370
# 2370 2400
# 2400 2430
# 2430 2460
# 2460 2490
# 2490 2520
# 2520 2550
# 2550 2580
# 2580 2610
# 2610 2640
# 2640 2670
# 2670 2700
# OneClassSVM(gamma='auto', kernel='linear', nu=0.05)
# [[2683    0]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    1.0000    0.9972      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9944      2698
#    macro avg     0.4972    0.5000    0.4986      2698
# weighted avg     0.9889    0.9944    0.9917      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.07)
# [[2354  329]
#  [   9    6]]
#               precision    recall  f1-score   support
#
#            0     0.9962    0.8774    0.9330      2683
#            1     0.0179    0.4000    0.0343        15
#
#     accuracy                         0.8747      2698
#    macro avg     0.5071    0.6387    0.4837      2698
# weighted avg     0.9908    0.8747    0.9280      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.08)
# [[2675    8]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    0.9970    0.9957      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9915      2698
#    macro avg     0.4972    0.4985    0.4979      2698
# weighted avg     0.9889    0.9915    0.9902      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.09)
# [[2244  439]
#  [  13    2]]
#               precision    recall  f1-score   support
#
#            0     0.9942    0.8364    0.9085      2683
#            1     0.0045    0.1333    0.0088        15
#
#     accuracy                         0.8325      2698
#    macro avg     0.4994    0.4849    0.4586      2698
# weighted avg     0.9887    0.8325    0.9035      2698
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OneClassSVM(gamma='auto', kernel='linear', nu=0.09999999999999999)
# [[2585   98]
#  [  12    3]]
#               precision    recall  f1-score   support
#
#            0     0.9954    0.9635    0.9792      2683
#            1     0.0297    0.2000    0.0517        15
#
#     accuracy                         0.9592      2698
#    macro avg     0.5125    0.5817    0.5154      2698
# weighted avg     0.9900    0.9592    0.9740      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.10999999999999999)
# [[2605   78]
#  [  13    2]]
#               precision    recall  f1-score   support
#
#            0     0.9950    0.9709    0.9828      2683
#            1     0.0250    0.1333    0.0421        15
#
#     accuracy                         0.9663      2698
#    macro avg     0.5100    0.5521    0.5125      2698
# weighted avg     0.9896    0.9663    0.9776      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.15)
# [[2369  314]
#  [   5   10]]
#               precision    recall  f1-score   support
#
#            0     0.9979    0.8830    0.9369      2683
#            1     0.0309    0.6667    0.0590        15
#
#     accuracy                         0.8818      2698
#    macro avg     0.5144    0.7748    0.4980      2698
# weighted avg     0.9925    0.8818    0.9320      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.16)
# [[2675    8]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    0.9970    0.9957      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9915      2698
#    macro avg     0.4972    0.4985    0.4979      2698
# weighted avg     0.9889    0.9915    0.9902      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.18000000000000002)
# [[2683    0]
#  [  15    0]]
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0     0.9944    1.0000    0.9972      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9944      2698
#    macro avg     0.4972    0.5000    0.4986      2698
# weighted avg     0.9889    0.9944    0.9917      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.19000000000000003)
# [[2610   73]
#  [  13    2]]
#               precision    recall  f1-score   support
#
#            0     0.9950    0.9728    0.9838      2683
#            1     0.0267    0.1333    0.0444        15
#
#     accuracy                         0.9681      2698
#    macro avg     0.5109    0.5531    0.5141      2698
# weighted avg     0.9897    0.9681    0.9786      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.20000000000000004)
# [[2554  129]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9942    0.9519    0.9726      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9466      2698
#    macro avg     0.4971    0.4760    0.4863      2698
# weighted avg     0.9886    0.9466    0.9672      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.22000000000000006)
# [[2507  176]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9941    0.9344    0.9633      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9292      2698
#    macro avg     0.4970    0.4672    0.4817      2698
# weighted avg     0.9885    0.9292    0.9579      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.25000000000000006)
# [[2337  346]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9957    0.8710    0.9292      2683
#            1     0.0142    0.3333    0.0273        15
#
#     accuracy                         0.8681      2698
#    macro avg     0.5050    0.6022    0.4783      2698
# weighted avg     0.9903    0.8681    0.9242      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.2700000000000001)
# [[2683    0]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    1.0000    0.9972      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9944      2698
#    macro avg     0.4972    0.5000    0.4986      2698
# weighted avg     0.9889    0.9944    0.9917      2698
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OneClassSVM(gamma='auto', kernel='linear', nu=0.2800000000000001)
# [[2336  347]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9957    0.8707    0.9290      2683
#            1     0.0142    0.3333    0.0272        15
#
#     accuracy                         0.8677      2698
#    macro avg     0.5050    0.6020    0.4781      2698
# weighted avg     0.9903    0.8677    0.9240      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.3100000000000001)
# [[2506  177]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9940    0.9340    0.9631      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9288      2698
#    macro avg     0.4970    0.4670    0.4816      2698
# weighted avg     0.9885    0.9288    0.9578      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.37000000000000016)
# [[2596   87]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9962    0.9676    0.9817      2683
#            1     0.0543    0.3333    0.0935        15
#
#     accuracy                         0.9640      2698
#    macro avg     0.5253    0.6505    0.5376      2698
# weighted avg     0.9909    0.9640    0.9767      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.38000000000000017)
# [[2578  105]
#  [  12    3]]
#               precision    recall  f1-score   support
#
#            0     0.9954    0.9609    0.9778      2683
#            1     0.0278    0.2000    0.0488        15
#
#     accuracy                         0.9566      2698
#    macro avg     0.5116    0.5804    0.5133      2698
# weighted avg     0.9900    0.9566    0.9726      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.4000000000000002)
# [[2678    5]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    0.9981    0.9963      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9926      2698
#    macro avg     0.4972    0.4991    0.4981      2698
# weighted avg     0.9889    0.9926    0.9907      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.4200000000000002)
# [[2683    0]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    1.0000    0.9972      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9944      2698
#    macro avg     0.4972    0.5000    0.4986      2698
# weighted avg     0.9889    0.9944    0.9917      2698
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OneClassSVM(gamma='auto', kernel='linear', nu=0.49000000000000027)
# [[2683    0]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    1.0000    0.9972      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9944      2698
#    macro avg     0.4972    0.5000    0.4986      2698
# weighted avg     0.9889    0.9944    0.9917      2698
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/anderson/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.07)
# [[2450  233]
#  [  14    1]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9132    0.9520      2683
#            1     0.0043    0.0667    0.0080        15
#
#     accuracy                         0.9085      2698
#    macro avg     0.4993    0.4899    0.4800      2698
# weighted avg     0.9888    0.9085    0.9468      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.08)
# [[2416  267]
#  [  14    1]]
#               precision    recall  f1-score   support
#
#            0     0.9942    0.9005    0.9450      2683
#            1     0.0037    0.0667    0.0071        15
#
#     accuracy                         0.8958      2698
#    macro avg     0.4990    0.4836    0.4761      2698
# weighted avg     0.9887    0.8958    0.9398      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.09)
# [[2422  261]
#  [  14    1]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9027    0.9463      2683
#            1     0.0038    0.0667    0.0072        15
#
#     accuracy                         0.8981      2698
#    macro avg     0.4990    0.4847    0.4767      2698
# weighted avg     0.9887    0.8981    0.9411      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.09999999999999999)
# [[2425  258]
#  [  14    1]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9038    0.9469      2683
#            1     0.0039    0.0667    0.0073        15
#
#     accuracy                         0.8992      2698
#    macro avg     0.4991    0.4853    0.4771      2698
# weighted avg     0.9888    0.8992    0.9417      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.10999999999999999)
# [[2606   77]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9713    0.9827      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9659      2698
#    macro avg     0.4971    0.4857    0.4913      2698
# weighted avg     0.9887    0.9659    0.9772      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.16)
# [[2420  263]
#  [   8    7]]
#               precision    recall  f1-score   support
#
#            0     0.9967    0.9020    0.9470      2683
#            1     0.0259    0.4667    0.0491        15
#
#     accuracy                         0.8996      2698
#    macro avg     0.5113    0.6843    0.4980      2698
# weighted avg     0.9913    0.8996    0.9420      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.17)
# [[2374  309]
#  [   8    7]]
#               precision    recall  f1-score   support
#
#            0     0.9966    0.8848    0.9374      2683
#            1     0.0222    0.4667    0.0423        15
#
#     accuracy                         0.8825      2698
#    macro avg     0.5094    0.6757    0.4899      2698
# weighted avg     0.9912    0.8825    0.9324      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.18000000000000002)
# [[2451  232]
#  [   9    6]]
#               precision    recall  f1-score   support
#
#            0     0.9963    0.9135    0.9531      2683
#            1     0.0252    0.4000    0.0474        15
#
#     accuracy                         0.9107      2698
#    macro avg     0.5108    0.6568    0.5003      2698
# weighted avg     0.9909    0.9107    0.9481      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.19000000000000003)
# [[2347  336]
#  [   9    6]]
#               precision    recall  f1-score   support
#
#            0     0.9962    0.8748    0.9315      2683
#            1     0.0175    0.4000    0.0336        15
#
#     accuracy                         0.8721      2698
#    macro avg     0.5069    0.6374    0.4826      2698
# weighted avg     0.9907    0.8721    0.9265      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2900000000000001)
# [[2517  166]
#  [  13    2]]
#               precision    recall  f1-score   support
#
#            0     0.9949    0.9381    0.9657      2683
#            1     0.0119    0.1333    0.0219        15
#
#     accuracy                         0.9337      2698
#    macro avg     0.5034    0.5357    0.4938      2698
# weighted avg     0.9894    0.9337    0.9604      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3000000000000001)
# [[2585   98]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9942    0.9635    0.9786      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9581      2698
#    macro avg     0.4971    0.4817    0.4893      2698
# weighted avg     0.9887    0.9581    0.9732      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3100000000000001)
# [[2560  123]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9942    0.9542    0.9738      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9489      2698
#    macro avg     0.4971    0.4771    0.4869      2698
# weighted avg     0.9886    0.9489    0.9683      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3200000000000001)
# [[2521  162]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9960    0.9396    0.9670      2683
#            1     0.0299    0.3333    0.0549        15
#
#     accuracy                         0.9362      2698
#    macro avg     0.5130    0.6365    0.5110      2698
# weighted avg     0.9907    0.9362    0.9619      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3300000000000001)
# [[2515  168]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9960    0.9374    0.9658      2683
#            1     0.0289    0.3333    0.0532        15
#
#     accuracy                         0.9340      2698
#    macro avg     0.5125    0.6354    0.5095      2698
# weighted avg     0.9907    0.9340    0.9607      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.34000000000000014)
# [[2511  172]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9960    0.9359    0.9650      2683
#            1     0.0282    0.3333    0.0521        15
#
#     accuracy                         0.9325      2698
#    macro avg     0.5121    0.6346    0.5086      2698
# weighted avg     0.9907    0.9325    0.9600      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.35000000000000014)
# [[2504  179]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9960    0.9333    0.9636      2683
#            1     0.0272    0.3333    0.0503        15
#
#     accuracy                         0.9299      2698
#    macro avg     0.5116    0.6333    0.5069      2698
# weighted avg     0.9906    0.9299    0.9586      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.36000000000000015)
# [[2452  231]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9959    0.9139    0.9532      2683
#            1     0.0212    0.3333    0.0398        15
#
#     accuracy                         0.9107      2698
#    macro avg     0.5086    0.6236    0.4965      2698
# weighted avg     0.9905    0.9107    0.9481      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.37000000000000016)
# [[2438  245]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9959    0.9087    0.9503      2683
#            1     0.0200    0.3333    0.0377        15
#
#     accuracy                         0.9055      2698
#    macro avg     0.5080    0.6210    0.4940      2698
# weighted avg     0.9905    0.9055    0.9452      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.38000000000000017)
# [[2251  432]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9956    0.8390    0.9106      2683
#            1     0.0114    0.3333    0.0221        15
#
#     accuracy                         0.8362      2698
#    macro avg     0.5035    0.5862    0.4664      2698
# weighted avg     0.9901    0.8362    0.9057      2698

# %%
from sklearn.decomposition import FactorAnalysis
pca = FactorAnalysis(n_components=9, random_state=0).fit(x_train)
novo_train  = pca.transform(x_train)
novo_test = []
for i in range (0,90):
    comeco = ((i*30))
    final = (((i+1)*30))
    if(final > end):
        final = end
    print(comeco,final)
    novo_test.append(pca.transform(x_test[comeco:final])  )

array_kernel = ['linear' , 'poly' , 'rbf' , 'sigmoid' , ] # 'precomputed'
models = []
nu_atual = 0.05
for c in array_kernel:
    while nu_atual <= 0.5:
        models.append(OneClassSVM(gamma='auto', kernel=c, nu=nu_atual).fit(novo_train))
        nu_atual += 0.01
    nu_atual = 0.05

for clf in models:
    preds = []
    for i in novo_test:
        y_test = clf.predict(i)
        y_test_final = [0 if i == 1 else 1 for i in y_test]
        preds += y_test_final
    if(accuracy_score(y_real, preds) > 0.83):
        print(clf)
        print(confusion_matrix(y_real, preds))
        print(classification_report(y_real, preds, digits = 4))
# Out:
# 0 30
# 30 60
# 60 90
# 90 120
# 120 150
# 150 180
# 180 210
# 210 240
# 240 270
# 270 300
# 300 330
# 330 360
# 360 390
# 390 420
# 420 450
# 450 480
# 480 510
# 510 540
# 540 570
# 570 600
# 600 630
# 630 660
# 660 690
# 690 720
# 720 750
# 750 780
# 780 810
# 810 840
# 840 870
# 870 900
# 900 930
# 930 960
# 960 990
# 990 1020
# 1020 1050
# 1050 1080
# 1080 1110
# 1110 1140
# 1140 1170
# 1170 1200
# 1200 1230
# 1230 1260
# 1260 1290
# 1290 1320
# 1320 1350
# 1350 1380
# 1380 1410
# 1410 1440
# 1440 1470
# 1470 1500
# 1500 1530
# 1530 1560
# 1560 1590
# 1590 1620
# 1620 1650
# 1650 1680
# 1680 1710
# 1710 1740
# 1740 1770
# 1770 1800
# 1800 1830
# 1830 1860
# 1860 1890
# 1890 1920
# 1920 1950
# 1950 1980
# 1980 2010
# 2010 2040
# 2040 2070
# 2070 2100
# 2100 2130
# 2130 2160
# 2160 2190
# 2190 2220
# 2220 2250
# 2250 2280
# 2280 2310
# 2310 2340
# 2340 2370
# 2370 2400
# 2400 2430
# 2430 2460
# 2460 2490
# 2490 2520
# 2520 2550
# 2550 2580
# 2580 2610
# 2610 2640
# 2640 2670
# 2670 2700
# OneClassSVM(gamma='auto', kernel='linear', nu=0.15)
# [[2340  343]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9957    0.8722    0.9299      2683
#            1     0.0144    0.3333    0.0275        15
#
#     accuracy                         0.8692      2698
#    macro avg     0.5051    0.6027    0.4787      2698
# weighted avg     0.9903    0.8692    0.9248      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.16)
# [[2523  160]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9941    0.9404    0.9665      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9351      2698
#    macro avg     0.4970    0.4702    0.4832      2698
# weighted avg     0.9886    0.9351    0.9611      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.37000000000000016)
# [[2549  134]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9941    0.9501    0.9716      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9448      2698
#    macro avg     0.4971    0.4750    0.4858      2698
# weighted avg     0.9886    0.9448    0.9662      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.47000000000000025)
# [[2635   48]
#  [  13    2]]
#               precision    recall  f1-score   support
#
#            0     0.9951    0.9821    0.9886      2683
#            1     0.0400    0.1333    0.0615        15
#
#     accuracy                         0.9774      2698
#    macro avg     0.5175    0.5577    0.5250      2698
# weighted avg     0.9898    0.9774    0.9834      2698
#
# OneClassSVM(gamma='auto', kernel='linear', nu=0.48000000000000026)
# [[2342  341]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9957    0.8729    0.9303      2683
#            1     0.0145    0.3333    0.0277        15
#
#     accuracy                         0.8699      2698
#    macro avg     0.5051    0.6031    0.4790      2698
# weighted avg     0.9903    0.8699    0.9253      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.05)
# [[2280  403]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9935    0.8498    0.9160      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8451      2698
#    macro avg     0.4967    0.4249    0.4580      2698
# weighted avg     0.9879    0.8451    0.9109      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.060000000000000005)
# [[2280  403]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9935    0.8498    0.9160      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8451      2698
#    macro avg     0.4967    0.4249    0.4580      2698
# weighted avg     0.9879    0.8451    0.9109      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.07)
# [[2272  411]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9934    0.8468    0.9143      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8421      2698
#    macro avg     0.4967    0.4234    0.4571      2698
# weighted avg     0.9879    0.8421    0.9092      2698

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=9, random_state=0).fit(x_train)
novo_train  = pca.transform(x_train)
novo_test = []
for i in range (0,90):
    comeco = ((i*30))
    final = (((i+1)*30))
    if(final > end):
        final = end
    print(comeco,final)
    novo_test.append(pca.transform(x_test[comeco:final])  )

array_kernel = ['poly' , 'rbf' , 'sigmoid' , ] # 'precomputed'
models = []
nu_atual = 0.4
for c in array_kernel:
    while nu_atual <= 0.5:
        models.append(OneClassSVM(gamma='auto', kernel=c, nu=nu_atual).fit(novo_train))
        nu_atual += 0.01
    nu_atual = 0.05

for clf in models:
    preds = []
    for i in novo_test:
        y_test = clf.predict(i)
        y_test_final = [0 if i == 1 else 1 for i in y_test]
        preds += y_test_final
    if(accuracy_score(y_real, preds) > 0.83):
        print(clf)
        print(confusion_matrix(y_real, preds))
        print(classification_report(y_real, preds, digits = 4))
# Out:
# 0 30
# 30 60
# 60 90
# 90 120
# 120 150
# 150 180
# 180 210
# 210 240
# 240 270
# 270 300
# 300 330
# 330 360
# 360 390
# 390 420
# 420 450
# 450 480
# 480 510
# 510 540
# 540 570
# 570 600
# 600 630
# 630 660
# 660 690
# 690 720
# 720 750
# 750 780
# 780 810
# 810 840
# 840 870
# 870 900
# 900 930
# 930 960
# 960 990
# 990 1020
# 1020 1050
# 1050 1080
# 1080 1110
# 1110 1140
# 1140 1170
# 1170 1200
# 1200 1230
# 1230 1260
# 1260 1290
# 1290 1320
# 1320 1350
# 1350 1380
# 1380 1410
# 1410 1440
# 1440 1470
# 1470 1500
# 1500 1530
# 1530 1560
# 1560 1590
# 1590 1620
# 1620 1650
# 1650 1680
# 1680 1710
# 1710 1740
# 1740 1770
# 1770 1800
# 1800 1830
# 1830 1860
# 1860 1890
# 1890 1920
# 1920 1950
# 1950 1980
# 1980 2010
# 2010 2040
# 2040 2070
# 2070 2100
# 2100 2130
# 2130 2160
# 2160 2190
# 2190 2220
# 2220 2250
# 2250 2280
# 2280 2310
# 2310 2340
# 2340 2370
# 2370 2400
# 2400 2430
# 2430 2460
# 2460 2490
# 2490 2520
# 2520 2550
# 2550 2580
# 2580 2610
# 2610 2640
# 2640 2670
# 2670 2700
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.05)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.060000000000000005)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.09999999999999999)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.10999999999999999)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.13999999999999999)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.16)
# [[2678    5]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    0.9981    0.9963      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9926      2698
#    macro avg     0.4972    0.4991    0.4981      2698
# weighted avg     0.9889    0.9926    0.9907      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.17)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.18000000000000002)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.22000000000000006)
# [[2302  381]
#  [  10    5]]
#               precision    recall  f1-score   support
#
#            0     0.9957    0.8580    0.9217      2683
#            1     0.0130    0.3333    0.0249        15
#
#     accuracy                         0.8551      2698
#    macro avg     0.5043    0.5957    0.4733      2698
# weighted avg     0.9902    0.8551    0.9167      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.23000000000000007)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.24000000000000007)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.26000000000000006)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2700000000000001)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.2900000000000001)
# [[2678    5]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9944    0.9981    0.9963      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9926      2698
#    macro avg     0.4972    0.4991    0.4981      2698
# weighted avg     0.9889    0.9926    0.9907      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3000000000000001)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3100000000000001)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.37000000000000016)
# [[2637   46]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9829    0.9886      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9774      2698
#    macro avg     0.4972    0.4914    0.4943      2698
# weighted avg     0.9888    0.9774    0.9831      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.38000000000000017)
# [[2637   46]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9829    0.9886      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9774      2698
#    macro avg     0.4972    0.4914    0.4943      2698
# weighted avg     0.9888    0.9774    0.9831      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.3900000000000002)
# [[2637   46]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9829    0.9886      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9774      2698
#    macro avg     0.4972    0.4914    0.4943      2698
# weighted avg     0.9888    0.9774    0.9831      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4000000000000002)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4200000000000002)
# [[2637   46]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9943    0.9829    0.9886      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.9774      2698
#    macro avg     0.4972    0.4914    0.4943      2698
# weighted avg     0.9888    0.9774    0.9831      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4300000000000002)
# [[2318  365]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9936    0.8640    0.9242      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8592      2698
#    macro avg     0.4968    0.4320    0.4621      2698
# weighted avg     0.9880    0.8592    0.9191      2698
#
# OneClassSVM(gamma='auto', kernel='sigmoid', nu=0.4400000000000002)
# [[2402  281]
#  [  15    0]]
#               precision    recall  f1-score   support
#
#            0     0.9938    0.8953    0.9420      2683
#            1     0.0000    0.0000    0.0000        15
#
#     accuracy                         0.8903      2698
#    macro avg     0.4969    0.4476    0.4710      2698
# weighted avg     0.9883    0.8903    0.9367      2698
